# %% [markdown]
# ### INSTALL DEPENDENCIS

# %%
# !pip install spotipy
# !pip install scikit-learn
# !pip install statsmodels
# Out:
# Requirement already satisfied: spotipy in c:\users\43699\.conda\envs\notebook\lib\site-packages (2.25.0)
# Requirement already satisfied: redis>=3.5.3 in c:\users\43699\.conda\envs\notebook\lib\site-packages (from spotipy) (5.2.1)
# Requirement already satisfied: requests>=2.25.0 in c:\users\43699\.conda\envs\notebook\lib\site-packages (from spotipy) (2.32.3)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\43699\.conda\envs\notebook\lib\site-packages (from spotipy) (2.2.3)
# Requirement already satisfied: async-timeout>=4.0.3 in c:\users\43699\.conda\envs\notebook\lib\site-packages (from redis>=3.5.3->spotipy) (5.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\43699\.conda\envs\notebook\lib\site-packages (from requests>=2.25.0->spotipy) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\43699\.conda\envs\notebook\lib\site-packages (from requests>=2.25.0->spotipy) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\43699\.conda\envs\notebook\lib\site-packages (from requests>=2.25.0->spotipy) (2024.12.14)
# Requirement already satisfied: scikit-learn in c:\users\43699\.conda\envs\notebook\lib\site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\43699\.conda\envs\notebook\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\43699\.conda\envs\notebook\lib\site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\43699\.conda\envs\notebook\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\43699\.conda\envs\notebook\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: statsmodels in c:\users\43699\.conda\envs\notebook\lib\site-packages (0.14.4)
# Requirement already satisfied: numpy<3,>=1.22.3 in c:\users\43699\.conda\envs\notebook\lib\site-packages (from statsmodels) (2.2.0)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\43699\.conda\envs\notebook\lib\site-packages (from statsmodels) (1.14.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\43699\.conda\envs\notebook\lib\site-packages (from statsmodels) (2.2.3)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\43699\.conda\envs\notebook\lib\site-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in c:\users\43699\.conda\envs\notebook\lib\site-packages (from statsmodels) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\43699\.conda\envs\notebook\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\43699\.conda\envs\notebook\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\43699\.conda\envs\notebook\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\43699\.conda\envs\notebook\lib\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.16.0)

# %% [markdown]
#  Import requirements

# %%
import pandas as pd
import sklearn
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from scipy.stats import pearsonr, spearmanr
from scipy.stats import pointbiserialr

# %%
client_id = "bc54923798704975b16cbe684b0766c9"
client_secret = "9e9a2e1ce2434454a0e7149d9b724461"

client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

print("Spotify API Authentication Successful!")
# Out:
# Spotify API Authentication Successful!

# %%
import requests
import base64

CLIENT_ID = "bc54923798704975b16cbe684b0766c9"
CLIENT_SECRET = "9e9a2e1ce2434454a0e7149d9b724461"

credentials = f"{CLIENT_ID}:{CLIENT_SECRET}"
encoded_credentials = base64.b64encode(credentials.encode()).decode()

url = "https://accounts.spotify.com/api/token"
headers = {
    "Authorization": f"Basic {encoded_credentials}",
}
data = {
    "grant_type": "client_credentials",
}

response = requests.post(url, headers=headers, data=data)
if response.status_code == 200:
    print("Access Token:", response.json()["access_token"])
else:
    print("Error:", response.status_code, response.text)
# Out:
# Access Token: BQCsu-yA2sJ3UaPNulPLpHJL5L7MFPwlQ2HCff26gNoNLSS-fCW8z7-x0d-7kWiUn-s2lR2NanUaMlL6UOixXUhXwf8d9MwZyxPHtELgPAF0aKCDh64

# %%
import requests

# input the access token
access_token = "BQCsu-yA2sJ3UaPNulPLpHJL5L7MFPwlQ2HCff26gNoNLSS-fCW8z7-x0d-7kWiUn-s2lR2NanUaMlL6UOixXUhXwf8d9MwZyxPHtELgPAF0aKCDh64"


url = "https://api.spotify.com/v1/search"
headers = {
    "Authorization": f"Bearer {access_token}"
}
params = {
    "q": "Top Hits",  # Search keyword
    "type": "playlist",
    "limit": 35  # Limit results to 35 playlists
}

response = requests.get(url, headers=headers, params=params)

if response.status_code == 200:
    search_results = response.json()
    playlists = search_results.get("playlists", {}).get("items", [])
    
    # Print details of each playlist safely
    for playlist in playlists:
        # Skip if the playlist is None
        if playlist is None:
            continue

        playlist_name = playlist.get('name', 'N/A')
        playlist_id = playlist.get('id', 'N/A')
        
        owner = playlist.get('owner')
        owner_name = owner.get('display_name', 'Unknown Owner') if owner else 'Unknown Owner'
        
        print(f"Playlist Name: {playlist_name}")
        print(f"Playlist ID: {playlist_id}")
        print(f"Owner: {owner_name}")
        print("------")
else:
    print("Failed to search for playlists:", response.json())
# Out:
# Playlist Name: BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hits 🎵
# Playlist ID: 5KJDMJe9EJ7QRz8FG2MIpI
# Owner: hotamazingnetwork
# ------
# Playlist Name: Hits 2025 🔥 🔥  Aktuelle Charts und die besten Songs 2025 🔝 🙌
# Playlist ID: 1CnDCN10TJZjw6K2H3gNRv
# Owner: Filtr Germany
# ------
# Playlist Name: HitRadio Ö3 2025 | TOP 40 [Wöchentlich Aktualisieren]
# Playlist ID: 12IHbu3MlYODzZvJHqdjbr
# Owner: Sounds of Someday | SOS
# ------
# Playlist Name: OE3 Hits
# Playlist ID: 3kCTvdDIMq1LzxKeJY4RQo
# Owner: nina.grillenberger
# ------
# Playlist Name: COUNTRY HITS 2025 🔥 New Country Songs + Top Hits
# Playlist ID: 4Jb4PDWREzNnbZcOHPcZPy
# Owner: Spot
# ------
# Playlist Name: Mega Hits des Jahres 2024 🇦🇹 Austria
# Playlist ID: 5lZUKfSSxmMe7dtn4xzYvH
# Owner: Digster Playlisten
# ------
# Playlist Name: Schlager Hits 2025 - Die Top 100 Schlager Charts - Schlagerchampions 2025
# Playlist ID: 0P745ihyc6DbSo66i7x3Dc
# Owner: Heinz Glawischnig
# ------
# Playlist Name: Ö3 Austria Top 40 | 4. Juni 2024
# Playlist ID: 6UJ85c1TfmqUqwk42U6QJA
# Owner: Hitradio Ö3
# ------
# Playlist Name: Radio Hits 2025
# Playlist ID: 28wnlqwIjjbc0wbG1074Dx
# Owner: CARSTN
# ------
# Playlist Name: top hits 2000-2025
# Playlist ID: 7E3uEa1emOcbZJuB8sFXeK
# Owner: oldskool
# ------
# Playlist Name: Acoustic Covers 2025 (Top 100)
# Playlist ID: 4uf0gphPVNtk4Uu0bxtdGA
# Owner: Unplugged
# ------
# Playlist Name: 90er und 2000er Top Hits
# Playlist ID: 1HCSOLU1vRfhXGvvRAad3C
# Owner: kallilucahsen
# ------
# Playlist Name: Albanian Hits 2025 - HITET SHQIP 2025 🇦🇱🇽🇰
# Playlist ID: 3bZMyxOFukSmGlXLuInoWN
# Owner: AlbanianHits Shqipe
# ------
# Playlist Name: Ö3 - Silvestercountdown 2024 Top 1000
# Playlist ID: 2vAFBoiPkz8m49CuqA4GJR
# Owner: ...
# ------
# Playlist Name: Reggae Classics 70s 80s & 90s | The Best Reggae Songs Of All Time | Reggae Music Hits | Top Reggae
# Playlist ID: 71R43lBYQZ6JQXH6LmRo1I
# Owner: Seu Gosto Pop
# ------
# Playlist Name: BEST HITS 2025 🔥 (TOP 100) Popular Songs
# Playlist ID: 0Ith1zB04YBERu89UovbNl
# Owner: LoudKult
# ------
# Playlist Name: Ö3 Hörer-Charts | 31. Mai 2024
# Playlist ID: 2pHqqz3F61MDWcOAlMC6ML
# Owner: Hitradio Ö3
# ------
# Playlist Name: 80s HITS | TOP 100 SONGS
# Playlist ID: 19PgP2QSGPcm6Ve8VhbtpG
# Owner: Filtr US
# ------

# %%
# Input the playlist_id( BEST HITS 2025)
playlist_id = "5KJDMJe9EJ7QRz8FG2MIpI"  
playlist_data = sp.playlist(playlist_id)

playlist_name = playlist_data["name"]
followers_count = playlist_data["followers"]["total"]

track_data = []


for i, track in enumerate(playlist_data["tracks"]["items"][:35]):
    track_name = track["track"]["name"]
    artist_name = track['track']["artists"][0]["name"]
    artist_id = track["track"]["artists"][0]["id"]
    release_date = track["track"]["album"]["release_date"]
    track_popularity = track["track"]["popularity"]

    track_data.append({
        "Track Number": i + 1,
        "Track Name": track_name,
        "Artist Name": artist_name,
        "Release Date": release_date,
        "Artist Id": artist_id,
        "Track Popularity": track_popularity,
        "Playlist Name": playlist_name,
        "Followers Count": followers_count
    })

    print(f"{i+1}. {track_name} by {artist_name}")
    print(f"   Released on: {release_date}")
    print(f"   Artist Id: {artist_id}")
    print(f"   Popularity: {track_popularity}")
    print(f"   Playlist Name: {playlist_name}")
    print(f"   Followers: {followers_count}\n")

df = pd.DataFrame(track_data)

# convert and print the DataFrame to a CSV file
df.to_csv("spotify_tracklist_data.csv", index=False)
print("Data successfully exported to 'spotify_tracklist_data.csv'.")
# Out:
# 1. Die With A Smile by Lady Gaga
#    Released on: 2024-08-16
#    Artist Id: 1HY2Jd0NmPuamShAr6KMms
#    Popularity: 100
#    Playlist Name: BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hits 🎵
#    Followers: 336668
#
# 2. BIRDS OF A FEATHER by Billie Eilish
#    Released on: 2024-05-17
#    Artist Id: 6qqNVTkY8uBg9cP3Jd7DAH
#    Popularity: 97
#    Playlist Name: BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hits 🎵
#    Followers: 336668
#
# 3. Espresso by Sabrina Carpenter
#    Released on: 2024-04-12
#    Artist Id: 74KM79TiuVKeVCqs8QtB0B
#    Popularity: 88
#    Playlist Name: BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hits 🎵
#    Followers: 336668
#
# 4. As It Was by Harry Styles
#    Released on: 2022-03-31
#    Artist Id: 6KImCVD70vtIoJWnq6nGn3
#    Popularity: 27
#    Playlist Name: BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hits 🎵
#    Followers: 336668
#
# 5. Life by ConKi
#    Released on: 2024-04-08
#    Artist Id: 2oBcbbUQy8Md3FYXifyPTF
#    Popularity: 67
#    Playlist Name: BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hits 🎵
#    Followers: 336668
#
# 6. Cruel Summer by Taylor Swift
#    Released on: 2019-08-23
#    Artist Id: 06HL4z0CvFAxyc27GXpf02
#    Popularity: 88
#    Playlist Name: BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hits 🎵
#    Followers: 336668
#
# 7. Good Luck, Babe! by Chappell Roan
#    Released on: 2024-04-05
#    Artist Id: 7GlBOeep6PqTfFi59PTUUN
#    Popularity: 92
#    Playlist Name: BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hits 🎵
#    Followers: 336668
#
# 8. Too Sweet by Hozier
#    Released on: 2024-03-22
#    Artist Id: 2FXC3k01G6Gw61bmprjgqS
#    Popularity: 47
#    Playlist Name: BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hits 🎵
#    Followers: 336668
#
# 9. Flowers by Miley Cyrus
#    Released on: 2023-01-13
#    Artist Id: 5YGY8feqx7naU7z4HrwZM6
#    Popularity: 33
#    Playlist Name: BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hits 🎵
#    Followers: 336668
#
# 10. Oh My Love by ConKi
#    Released on: 2024-09-12
#    Artist Id: 2oBcbbUQy8Md3FYXifyPTF
#    Popularity: 65
#    Playlist Name: BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hits 🎵
#    Followers: 336668
#
# 11. Beautiful Things by Benson Boone
#    Released on: 2024-01-18
#    Artist Id: 22wbnEMDvgVIAGdFeek6ET
#    Popularity: 85
#    Playlist Name: BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hits 🎵
#    Followers: 336668
#
# 12. STAY (with Justin Bieber) by The Kid LAROI
#    Released on: 2021-07-09
#    Artist Id: 2tIP7SsRs7vjIcLrU85W8J
#    Popularity: 78
#    Playlist Name: BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hits 🎵
#    Followers: 336668
#
# 13. A Bar Song (Tipsy) by Shaboozey
#    Released on: 2024-04-12
#    Artist Id: 3y2cIKLjiOlp1Np37WiUdH
#    Popularity: 86
#    Playlist Name: BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hits 🎵
#    Followers: 336668
#
# 14. Ocean by ConKi
#    Released on: 2022-02-10
#    Artist Id: 2oBcbbUQy8Md3FYXifyPTF
#    Popularity: 57
#    Playlist Name: BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hits 🎵
#    Followers: 336668
#
# 15. i like the way you kiss me by Artemas
#    Released on: 2024-03-19
#    Artist Id: 0PCCGZ0wGLizHt2KZ7hhA2
#    Popularity: 83
#    Playlist Name: BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hits 🎵
#    Followers: 336668
#
# 16. Please Please Please by Sabrina Carpenter
#    Released on: 2024-06-06
#    Artist Id: 74KM79TiuVKeVCqs8QtB0B
#    Popularity: 85
#    Playlist Name: BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hits 🎵
#    Followers: 336668
#
# 17. I Ain't Worried by OneRepublic
#    Released on: 2022-05-13
#    Artist Id: 5Pwc4xIPtQLFEnJriah9YJ
#    Popularity: 79
#    Playlist Name: BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hits 🎵
#    Followers: 336668
#
# 18. Unholy (feat. Kim Petras) by Sam Smith
#    Released on: 2022-09-22
#    Artist Id: 2wY79sveU1sp5g7SokKOiI
#    Popularity: 76
#    Playlist Name: BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hits 🎵
#    Followers: 336668
#
# 19. Sleep by ConKi
#    Released on: 2023-06-01
#    Artist Id: 2oBcbbUQy8Md3FYXifyPTF
#    Popularity: 61
#    Playlist Name: BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hits 🎵
#    Followers: 336668
#
# 20. vampire by Olivia Rodrigo
#    Released on: 2023-06-30
#    Artist Id: 1McMsnEElThX1knmY4oliG
#    Popularity: 17
#    Playlist Name: BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hits 🎵
#    Followers: 336668
#
# 21. Cold Heart - PNAU Remix by Elton John
#    Released on: 2021-08-13
#    Artist Id: 3PhoLpVuITZKcymswpck5b
#    Popularity: 79
#    Playlist Name: BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hits 🎵
#    Followers: 336668
#
# 22. greedy by Tate McRae
#    Released on: 2023-09-15
#    Artist Id: 45dkTj5sMRSjrmBSBeiHym
#    Popularity: 85
#    Playlist Name: BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hits 🎵
#    Followers: 336668
#
# 23. I'll Be There by ConKi
#    Released on: 2022-08-11
#    Artist Id: 2oBcbbUQy8Md3FYXifyPTF
#    Popularity: 56
#    Playlist Name: BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hits 🎵
#    Followers: 336668
#
# 24. Paint The Town Red by Doja Cat
#    Released on: 2023-08-04
#    Artist Id: 5cj0lLjcoR7YOSnhnX0Po5
#    Popularity: 78
#    Playlist Name: BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hits 🎵
#    Followers: 336668
#
# 25. Ghost by Justin Bieber
#    Released on: 2021-03-19
#    Artist Id: 1uNFoZAHBGtllmzznpCI3s
#    Popularity: 68
#    Playlist Name: BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hits 🎵
#    Followers: 336668
#
# 26. Lose Control by Teddy Swims
#    Released on: 2023-09-15
#    Artist Id: 33qOK5uJ8AR2xuQQAhHump
#    Popularity: 89
#    Playlist Name: BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hits 🎵
#    Followers: 336668
#
# 27. Let It Go by ConKi
#    Released on: 2023-02-16
#    Artist Id: 2oBcbbUQy8Md3FYXifyPTF
#    Popularity: 54
#    Playlist Name: BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hits 🎵
#    Followers: 336668
#
# 28. One Of The Girls (with JENNIE, Lily Rose Depp) by The Weeknd
#    Released on: 2024-02-09
#    Artist Id: 1Xyo4u8uXC1ZmMpatF05PJ
#    Popularity: 63
#    Playlist Name: BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hits 🎵
#    Followers: 336668
#
# 29. I Had Some Help (Feat. Morgan Wallen) by Post Malone
#    Released on: 2024-05-10
#    Artist Id: 246dkjvS1zLTtiykXe5h60
#    Popularity: 83
#    Playlist Name: BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hits 🎵
#    Followers: 336668
#
# 30. Daylight by David Kushner
#    Released on: 2023-04-14
#    Artist Id: 33NVpKoXjItPwUJTMZIOiY
#    Popularity: 81
#    Playlist Name: BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hits 🎵
#    Followers: 336668
#
# 31. Bubbly by ConKi
#    Released on: 2023-05-11
#    Artist Id: 2oBcbbUQy8Md3FYXifyPTF
#    Popularity: 53
#    Playlist Name: BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hits 🎵
#    Followers: 336668
#
# 32. I'm Good (Blue) by David Guetta
#    Released on: 2022-08-26
#    Artist Id: 1Cs0zKBU1kc0i8ypK3B9ai
#    Popularity: 84
#    Playlist Name: BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hits 🎵
#    Followers: 336668
#
# 33. Calm Down (with Selena Gomez) by Rema
#    Released on: 2022-08-25
#    Artist Id: 46pWGuE3dSwY3bMMXGBvVS
#    Popularity: 79
#    Playlist Name: BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hits 🎵
#    Followers: 336668
#
# 34. Glimpse of Us by Joji
#    Released on: 2022-06-10
#    Artist Id: 3MZsBdqDrRTJihTHQrO6Dq
#    Popularity: 63
#    Playlist Name: BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hits 🎵
#    Followers: 336668
#
# 35. Roaring 20s by DVNY
#    Released on: 2024-09-26
#    Artist Id: 6bZPyY7fpgegmdBHwbbu77
#    Popularity: 54
#    Playlist Name: BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hits 🎵
#    Followers: 336668
#
# Data successfully exported to 'spotify_tracklist_data.csv'.

# %% [markdown]
# ### STEP 2: FILTER AND CLEAN DATA

# %%
# Load the dataset
spotify_tracklist_file_path = pd.read_csv(r"C:\Users\43699\Downloads\spotify_tracklist_data.csv")

# Display the last few rows 
spotify_tracklist_file_path.tail(5)
# Out:
#     Track Number                     Track Name   Artist Name Release Date  \
# 30            31                         Bubbly         ConKi   2023-05-11
# 31            32                I'm Good (Blue)  David Guetta   2022-08-26
# 32            33  Calm Down (with Selena Gomez)          Rema   2022-08-25
# 33            34                  Glimpse of Us          Joji   2022-06-10
# 34            35                    Roaring 20s          DVNY   2024-09-26
#
#                  Artist Id  Track Popularity  \
# 30  2oBcbbUQy8Md3FYXifyPTF                53
# 31  1Cs0zKBU1kc0i8ypK3B9ai                84
# 32  46pWGuE3dSwY3bMMXGBvVS                79
# 33  3MZsBdqDrRTJihTHQrO6Dq                63
# 34  6bZPyY7fpgegmdBHwbbu77                54
#
#                                         Playlist Name  Followers Count
# 30  BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hit...           336668
# 31  BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hit...           336668
# 32  BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hit...           336668
# 33  BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hit...           336668
# 34  BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hit...           336668

# %%
# Display basic column information names and data types 
df.info()
 
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Track Number      35 non-null     int64
#  1   Track Name        35 non-null     object
#  2   Artist Name       35 non-null     object
#  3   Release Date      35 non-null     object
#  4   Artist Id         35 non-null     object
#  5   Track Popularity  35 non-null     int64
#  6   Playlist Name     35 non-null     object
#  7   Followers Count   35 non-null     int64
# dtypes: int64(3), object(5)
# memory usage: 2.3+ KB
#        Track Number  Track Popularity  Followers Count
# count     35.000000         35.000000             35.0
# mean      18.000000         70.857143         336668.0
# std       10.246951         19.575109              0.0
# min        1.000000         17.000000         336668.0
# 25%        9.500000         59.000000         336668.0
# 50%       18.000000         78.000000         336668.0
# 75%       26.500000         85.000000         336668.0
# max       35.000000        100.000000         336668.0

# %%
# Check for missing figures  
missing_values = df.isnull().sum()
print("Missing Values:\n", missing_values)
# Out:
# Missing Values:
#  Track Number        0
# Track Name          0
# Artist Name         0
# Release Date        0
# Artist Id           0
# Track Popularity    0
# Playlist Name       0
# Followers Count     0
# dtype: int64

# %%
# print the column names in the DataFrame
print("Column Names in DataFrame:", df.columns)
# Out:
# Column Names in DataFrame: Index(['Track Number', 'Track Name', 'Artist Name', 'Release Date',
#        'Artist Id', 'Track Popularity', 'Playlist Name', 'Followers Count'],
#       dtype='object')

# %% [markdown]
# ###  Data Analysis

# %%
# load dataset
spotify_tracklist = pd.read_csv(r"C:\Users\43699\Downloads\spotify_tracklist_data.csv")
print(spotify_tracklist.head())
# Out:
#    Track Number          Track Name        Artist Name Release Date  \
# 0             1    Die With A Smile          Lady Gaga   2024-08-16
# 1             2  BIRDS OF A FEATHER      Billie Eilish   2024-05-17
# 2             3            Espresso  Sabrina Carpenter   2024-04-12
# 3             4           As It Was       Harry Styles   2022-03-31
# 4             5                Life              ConKi   2024-04-08
#
#                 Artist Id  Track Popularity  \
# 0  1HY2Jd0NmPuamShAr6KMms               100
# 1  6qqNVTkY8uBg9cP3Jd7DAH                97
# 2  74KM79TiuVKeVCqs8QtB0B                88
# 3  6KImCVD70vtIoJWnq6nGn3                27
# 4  2oBcbbUQy8Md3FYXifyPTF                67
#
#                                        Playlist Name  Followers Count
# 0  BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hit...           336668
# 1  BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hit...           336668
# 2  BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hit...           336668
# 3  BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hit...           336668
# 4  BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hit...           336668

# %%
# Display basic column information names and data types 
df.info()

df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Track Number      35 non-null     int64
#  1   Track Name        35 non-null     object
#  2   Artist Name       35 non-null     object
#  3   Release Date      35 non-null     object
#  4   Artist Id         35 non-null     object
#  5   Track Popularity  35 non-null     int64
#  6   Playlist Name     35 non-null     object
#  7   Followers Count   35 non-null     int64
# dtypes: int64(3), object(5)
# memory usage: 2.3+ KB
#        Track Number  Track Popularity  Followers Count
# count     35.000000         35.000000             35.0
# mean      18.000000         70.857143         336668.0
# std       10.246951         19.575109              0.0
# min        1.000000         17.000000         336668.0
# 25%        9.500000         59.000000         336668.0
# 50%       18.000000         78.000000         336668.0
# 75%       26.500000         85.000000         336668.0
# max       35.000000        100.000000         336668.0

# %%
# using the numerical column create and plot the histogram distribution of followers count and track popularity
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.hist(spotify_tracklist["Followers Count"], bins=30, edgecolor="black")
plt.title("Distribution of Followers Count")
plt.xlabel("Followers Count")
plt.ylabel("Frequency")

plt.subplot(1, 2, 2)
plt.hist(data["Track Popularity"], bins=30, edgecolor="black")
plt.title("Distribution of Track Popularity")
plt.xlabel("Track Popularity")
plt.ylabel("Frequency")

plt.tight_layout()
plt.show()

# %%
# using the numerical column create and display thebox plot  of followers count and track popularity 
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.boxplot(y=spotify_tracklist['Followers Count'])
plt.title('Boxplot of Followers Count')

plt.subplot(1, 2, 2)
sns.boxplot(y=data['Track Popularity'])
plt.title('Boxplot of Track Popularity')

plt.tight_layout()
plt.show()

# %%
# convert the 'release date' to datetime format
spotify_tracklist["Release Date"] = pd.to_datetime(spotify_tracklist["Release Date"], errors='coerce')

#Create a new column for "is new artist" for the last two years 
spotify_tracklist["Is New Artist"] =spotify_tracklist["Release Date"] >= pd.Timestamp(datetime.now().year - 2, 1, 1)

new_artist_count =spotify_tracklist["Is New Artist"].value_counts()

# create and display Bar plot for the count of new and existing artists
plt.figure(figsize=(6, 6))
sns.barplot(x=new_artist_count.index, y=new_artist_count.values)
plt.title('Count of New vs. Existing Artists')
plt.xlabel('Is New Artist?')
plt.ylabel('Count')
plt.xticks(ticks=[0, 1], labels=['Existing Artist', 'New Artist'])
plt.show()

# %%
# Save the new dataset that contains 'Is New Artist' column and print
spotify_tracklist.to_csv(r"C:\Users\43699\Downloads\spotify_tracklist_with_new_artists.csv", index=False)

print("CSV file containing both new and existing artists successfully saved!")
# Out:
# CSV file containing both new and existing artists successfully saved!

# %%
# Load the new dataset 
data = pd.read_csv(r"C:\Users\43699\Downloads\spotify_tracklist_with_new_artists.csv")

# Display the first few rows and check the data types
print(data.head())
print(data.info())
# Out:
#    Track Number          Track Name        Artist Name Release Date  \
# 0             1    Die With A Smile          Lady Gaga   2024-08-16
# 1             2  BIRDS OF A FEATHER      Billie Eilish   2024-05-17
# 2             3            Espresso  Sabrina Carpenter   2024-04-12
# 3             4           As It Was       Harry Styles   2022-03-31
# 4             5                Life              ConKi   2024-04-08
#
#                 Artist Id  Track Popularity  \
# 0  1HY2Jd0NmPuamShAr6KMms               100
# 1  6qqNVTkY8uBg9cP3Jd7DAH                97
# 2  74KM79TiuVKeVCqs8QtB0B                88
# 3  6KImCVD70vtIoJWnq6nGn3                27
# 4  2oBcbbUQy8Md3FYXifyPTF                67
#
#                                        Playlist Name  Followers Count  \
# 0  BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hit...           336668
# 1  BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hit...           336668
# 2  BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hit...           336668
# 3  BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hit...           336668
# 4  BEST HITS 2025 🔥 Popular Songs 🎵 Top Music Hit...           336668
#
#    Is New Artist
# 0           True
# 1           True
# 2           True
# 3          False
# 4           True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Track Number      35 non-null     int64
#  1   Track Name        35 non-null     object
#  2   Artist Name       35 non-null     object
#  3   Release Date      35 non-null     object
#  4   Artist Id         35 non-null     object
#  5   Track Popularity  35 non-null     int64
#  6   Playlist Name     35 non-null     object
#  7   Followers Count   35 non-null     int64
#  8   Is New Artist     35 non-null     bool
# dtypes: bool(1), int64(3), object(5)
# memory usage: 2.3+ KB
# None

# %%
# Calculate to see new artist ratio per playlist 
data['new_artist_ratio'] = data.groupby('playlist name')['is_new_artist'].transform('sum') / data.groupby('playlist name')['track number'].transform('count')


print(data.head())
# Out:
#    track number                  track name    artist name release date  \
# 0             1  i like the way you kiss me        Artemas   2024-03-19
# 1             2                  Mittelmeer       Pashanim   2024-05-23
# 2             3                       LUNCH  Billie Eilish   2024-05-17
# 3             4            Beautiful Things   Benson Boone   2024-01-18
# 4             5                   Too Sweet         Hozier   2024-03-22
#
#    track popularity                     playlist name  followers count  \
# 0                83  Ö3 Austria Top 40 | 4. Juni 2024            43001
# 1                65  Ö3 Austria Top 40 | 4. Juni 2024            43001
# 2                85  Ö3 Austria Top 40 | 4. Juni 2024            43001
# 3                85  Ö3 Austria Top 40 | 4. Juni 2024            43001
# 4                78  Ö3 Austria Top 40 | 4. Juni 2024            43001
#
#    is_new_artist  new_artist_ratio
# 0           True          0.971429
# 1           True          0.971429
# 2           True          0.971429
# 3           True          0.971429
# 4           True          0.971429

# %%
# create and display the boxplot for "Track Popularity" 
plt.figure(figsize=(8, 6))
sns.boxplot(y=data["Track Popularity"])
plt.title("Boxplot for Track Popularity")
plt.show()

Q3 = data["Track Popularity"].quantile(0.75)
IQR = Q3 - Q1

filtered_data = data[
    (data["Track Popularity"] >= Q1 - 1.5 * IQR) & 
    (data["Track Popularity"] <= Q3 + 1.5 * IQR)
]

filtered_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34 entries, 0 to 34
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Track Number      34 non-null     int64
#  1   Track Name        34 non-null     object
#  2   Artist Name       34 non-null     object
#  3   Release Date      34 non-null     object
#  4   Artist Id         34 non-null     object
#  5   Track Popularity  34 non-null     int64
#  6   Playlist Name     34 non-null     object
#  7   Followers Count   34 non-null     int64
#  8   Is New Artist     34 non-null     bool
# dtypes: bool(1), int64(3), object(5)
# memory usage: 2.4+ KB

# %%
# Calculate and display Point-Biserial Correlation coeffiecient
corr_pointbiserial, p_value_pointbiserial = pointbiserialr(
    data["Track Popularity"], data["Is New Artist"]
)

print(f"Point-Biserial Correlation Coefficient: {corr_pointbiserial}")
print(f"P-value: {p_value_pointbiserial}")
# Out:
# Point-Biserial Correlation Coefficient: 0.05080923491542457
# P-value: 0.7719217899190879

# %%
# Create and dissplay he scatter plot between Track Popularity vs. New Artist
plt.figure(figsize=(8, 6))
sns.scatterplot(x="Track Popularity", y="Is New Artist", data=data)
plt.title("Track Popularity vs. New Artist Discovery")
plt.xlabel("Track Popularity")
plt.ylabel("Is New Artist? (1 = New, 0 = Existing)")
plt.show()

# %%
# Create and display the box plot base on artist type 
plt.figure(figsize=(8, 6))
sns.boxplot(x="Is New Artist", y="Track Popularity", data=data)
plt.title("Track Popularity Distribution Based on Artist Type")
plt.xlabel("Is New Artist?")
plt.ylabel("Track Popularity")
plt.show()

# %%
# Create and display the histogram to show the distribution of track popularity
plt.figure(figsize=(8, 6))
sns.histplot(data["Track Popularity"], bins=20, kde=True)
plt.title("Distribution of Track Popularity")
plt.xlabel("Track Popularity")
plt.ylabel("Frequency")
plt.show()

# %%
# Create and display regression plot for trend line between track popularity and new artist
plt.figure(figsize=(8, 6))
sns.regplot(x="Track Popularity", y="Is New Artist", data=data, logistic=True)
plt.title("Trend Line for Track Popularity vs. New Artist")
plt.xlabel("Track Popularity")
plt.ylabel("Is New Artist?")
plt.show()
